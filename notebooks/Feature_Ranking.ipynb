# %% [markdown]
# ## Feature ranking with elimination

# %% [raw]
# Algorithm for feature elimination:
#
# Repeat N times, where n is the total number of features
# -For a feature in the list_of_features:
# --train a model (fixed parameters) using all the features in the list_of_features except feature
# --get performance score for the trained model
# -remove the feature with least significance to the performance of the model
# --list_of_features.pop(feature)

# %%
import numpy as np
from sklearn.model_selection import KFold, cross_val_score
from xgboost import XGBRegressor
from pathlib import Path
import pickle
import pandas as pd
from matplotlib import pyplot as plt
from xgboost import XGBRegressor
import numpy as np

# %%
def get_scoring_funtion_polarity(scoring):
    polarity = {
        "explained_variance": True,
        "max_error": False,
        "neg_mean_absolute_error": False,
        "neg_mean_squared_error": False,
        "neg_root_mean_squared_error": False,
        "neg_mean_squared_log_error": False,
        "neg_median_absolute_error": False,
        "r2": True,
        "neg_mean_poisson_deviance": False,
        "neg_mean_gamma_deviance": False,
        "neg_mean_absolute_percentage_error": False
    }

    return polarity[scoring]

def get_score_without_feature(X, y, features_to_drop, scoring, model,n_splits=3):

    kf = KFold(n_splits=n_splits, shuffle=True, random_state=3)
    cv_scores = cross_val_score(model, X.drop(features_to_drop, axis=1).values, y.values, cv=kf, scoring=scoring, n_jobs=-1)
    mean_score = np.mean(cv_scores)
    return mean_score


def find_least_important_feature(X, y, scoring, model, n_splits):
    is_polarity_positive = get_scoring_funtion_polarity(scoring)
    intermediate_results = {}
    for featureindex, feature_name in enumerate(X.columns):
        score_without_feature = get_score_without_feature(X, y, feature_name, scoring, model, n_splits)
        intermediate_results[feature_name] = score_without_feature
        print("Getting score for: ", feature_name, score_without_feature)

    # calculate the results        
    if is_polarity_positive:
        lowest_feature = None
        lowest_score = -99999
        for feature_name in intermediate_results.keys():
            score_without_feature = intermediate_results[feature_name]
            if score_without_feature >= lowest_score:
                lowest_score = score_without_feature
                lowest_feature = feature_name
            del score_without_feature
    else:
        lowest_feature = None
        lowest_score = 99999
        for feature_name in intermediate_results.keys():
            score_without_feature = intermediate_results[feature_name]
            if score_without_feature <= lowest_score:
                lowest_score = score_without_feature
                lowest_feature = feature_name
            del score_without_feature

    results = {}
    results["lowest_score"] = lowest_score
    results["lowest_feature"] = lowest_feature
    results["intermediate_results"] = intermediate_results
    del intermediate_results
    del lowest_feature
    del lowest_score
    return results

def feature_ranking_elimination(X, y, min_features_required, scoring, model, n_splits):
    results = {}
    current_total_feature = X.shape[1]

    count = 1
    results[current_total_feature] = find_least_important_feature(X, y, scoring, model, n_splits)

    current_X = X.drop(results[current_total_feature]["lowest_feature"], axis=1)
    current_total_feature = current_X.shape[1]

    count = count + 1
    while (current_total_feature > min_features_required):
        print("Staring experiment for: ", current_total_feature)
        results[current_total_feature] = find_least_important_feature(current_X, y, scoring, model, n_splits)
        print("Results of ", str(count), " iteration:", results[current_total_feature]["lowest_score"])
        current_X = current_X.drop(results[current_total_feature]["lowest_feature"], axis=1)
        current_total_feature = current_X.shape[1]
        count = count + 1

    return results

# %% [markdown]
# ## Recursive feature elimination with cross-validation

# %%
input_files = [
    Path("../data/formated_dataset.csv"),
    Path("../data/scaler_df.csv"),
    Path("../data/quantile_df.csv"),
    Path("../data/max_abs_df.csv")
]


input_file = input_files[2]
print("Input file: ",input_file)
df = pd.read_csv(input_file).astype('float32')
df = df[~df.isin([np.nan, np.inf, -np.inf,-9999.0]).any(1)]
y = df['target']
X = df.drop("target",axis=1)


min_features_required=2
model=XGBRegressor(objective='reg:squarederror', tree_method='gpu_hist', gpu_id=0, n_jobs=-1)
n_splits=3

scorings = ["r2"]

for scoring in scorings:
    print("Scoring funtion: ",scoring)
    results = feature_ranking_elimination(X,y, min_features_required, scoring, model, n_splits)
    
    output_file_name = str(input_file.stem)+"_scorings"+"_1feb.pkl"
    file = open(output_file_name, 'wb')
    pickle.dump(results, file)
    file.close()


    plot_1_data = []
    for exp_no in results.keys():
            plot_1_data.append((exp_no,results[exp_no]["lowest_score"]))

    plt.scatter(*zip(*plot_1_data))
    plt.gca().invert_xaxis()
    # plt.ylim(0,0.5)
    plt.xlabel("Number of features in this experiment")
    plt.ylabel("Score for the weakest the feature")
    plt.show()

# %%
from pathlib import Path
import pickle
import pandas as pd
from matplotlib import pyplot as plt
from xgboost import XGBRegressor
import numpy as np

input_files = [
    Path("../data/formated_dataset.csv"),
    Path("../data/scaler_df.csv"),
    Path("../data/quantile_df.csv"),
    Path("../data/max_abs_df.csv")
]


input_file = input_files[2]
print("Input file: ",input_file)
df = pd.read_csv(input_file).astype('float32')
df = df[~df.isin([np.nan, np.inf, -np.inf,-9999.0]).any(1)]
y = df['target']
X = df.drop("target",axis=1)


min_features_required=2
model=XGBRegressor(objective='reg:squarederror', tree_method='gpu_hist', gpu_id=0, n_jobs=-1)
n_splits=3

scorings = ["neg_root_mean_squared_error"]

for scoring in scorings:
    print("Scoring funtion: ",scoring)
    results = feature_ranking_elimination(X,y, min_features_required, scoring, model, n_splits)
    
    output_file_name = str(input_file.stem)+"_scorings"+"_1feb.pkl"
    file = open(output_file_name, 'wb')
    pickle.dump(results, file)
    file.close()


    plot_1_data = []
    for exp_no in results.keys():
            plot_1_data.append((exp_no,results[exp_no]["lowest_score"]))

    plt.scatter(*zip(*plot_1_data))
    plt.gca().invert_xaxis()
    # plt.ylim(0,0.5)
    plt.xlabel("Number of features in this experiment")
    plt.ylabel("Score for the weakest the feature")
    plt.show()
# Out:
# Input file:  ../data/quantile_df.csv
# Scoring funtion:  neg_root_mean_squared_error
# Getting score for:  tpi_300 -0.13739939530690512
# Getting score for:  Grav_lane_clip -0.1381209840377172
# Getting score for:  clim_PTA_albers -0.13805154462655386
# Getting score for:  be-30y-85m-avg-ND-RED-BLUE.filled.lzw.nodata -0.13764223456382751
# Getting score for:  be-30y-85m-avg_BLUE+SWIR2 -0.13781333963076273
# Getting score for:  3dem_mag1_fin -0.13858643174171448
# Getting score for:  ceno_euc_aust1 -0.13864854474862418
# Getting score for:  be-l8-all-85m-avg-BLUE.filled.lzw.nodata -0.13765077789624533
# Getting score for:  be-30y-85m-avg-ND-SWIR1-NIR.filled.lzw.nodata -0.13774276276429495
# Getting score for:  Thorium_2016 -0.1378012498219808
# Getting score for:  dem_fill -0.13893455266952515
# Getting score for:  relief_elev_focalrange1000m_3s -0.13766202827294668
# Getting score for:  LATITUDE_GRID1_clip -0.1379438191652298
# Getting score for:  LOC_distance_to_coast -0.1386656016111374
# Getting score for:  be-30y-85m-avg-SWIR1.filled.lzw.nodata -0.13744460542996725
# Getting score for:  clim_EPA_albers -0.1377263863881429
# Getting score for:  be-30y-85m-avg-ND-SWIR1-SWIR2.filled.lzw.nodata -0.13833721975485483
# Getting score for:  relief_roughness -0.1377115547657013
# Getting score for:  LONGITUDE_GRID1_clip -0.14015948275725046
# Getting score for:  si_geol1 -0.13841753701368967
# Getting score for:  be-30y-85m-avg-SWIR2.filled.lzw.nodata -0.13767523566881815
# Getting score for:  national_Wii_RF_multirandomforest_prediction -0.13810026148955026
# Getting score for:  3dem_mag2 -0.13845298687616983
# Getting score for:  clim_WDA_albers -0.13800503313541412
# Getting score for:  Dose_2016 -0.13754078249136606
# Getting score for:  be-30y-85m-avg-GREEN.filled.lzw.nodata -0.1377209722995758
# Getting score for:  be-30y-85m-avg-CLAY-PC2.filled.lzw.nodata -0.13780281444390616
# Getting score for:  Clim_Prescott_LindaGregory -0.13829208413759866
# Getting score for:  Potassium_2016 -0.1380116194486618
# Getting score for:  mrvbf_9 -0.13828957080841064
# Getting score for:  Rad2016K_Th -0.13783937195936838
# Getting score for:  be-30y-85m-avg-ND-NIR-GREEN.filled.lzw.nodata -0.1382809430360794
# Getting score for:  be-l8-all-85m-avg-NIR.filled.lzw.nodata -0.1376816580692927
# Getting score for:  be-30y-85m-avg-RED.filled.lzw.nodata -0.13795696198940277
# Getting score for:  slope_fill2 -0.13788968324661255
# Getting score for:  clim_RSM_albers -0.13819237550099692
# Getting score for:  relief_elev_focalrange300m_3s -0.1375659058491389
# Getting score for:  relief_mrvbf_3s_mosaic -0.13804071148236594
# Getting score for:  Rad2016U_Th -0.13770252466201782
# Getting score for:  3dem_mag0.fin -0.13782704869906107
# Getting score for:  s2-dpca-85m_1 -0.13786702851454416
# Getting score for:  s2-dpca-85m_2 -0.13749622801939645
# Getting score for:  s2-dpca-85m_3 -0.13793445626894632
# Getting score for:  water-85m_1 -0.13816478848457336
# Getting score for:  water-85m_2 -0.13801032801469168
# Getting score for:  water-85m_3 -0.13789457579453787
# Getting score for:  saga_wetSM_85_reprojected -0.1378210484981537
# Staring experiment for:  46
# Getting score for:  tpi_300 -0.1405206819375356
# Getting score for:  Grav_lane_clip -0.14080296456813812
# Getting score for:  clim_PTA_albers -0.1405919392903646
# Getting score for:  be-30y-85m-avg-ND-RED-BLUE.filled.lzw.nodata -0.14065165321032205
# Getting score for:  be-30y-85m-avg_BLUE+SWIR2 -0.1405720959107081
# Getting score for:  3dem_mag1_fin -0.14090674618879953
# Getting score for:  ceno_euc_aust1 -0.14083892603715262
# Getting score for:  be-l8-all-85m-avg-BLUE.filled.lzw.nodata -0.13968012730280557
# Getting score for:  be-30y-85m-avg-ND-SWIR1-NIR.filled.lzw.nodata -0.140601913134257
# Getting score for:  Thorium_2016 -0.14013693730036417
# Getting score for:  dem_fill -0.14237058659394583
# Getting score for:  relief_elev_focalrange1000m_3s -0.14047835767269135
# Getting score for:  LATITUDE_GRID1_clip -0.1415706624587377
# Getting score for:  LOC_distance_to_coast -0.14138381679852804
# Getting score for:  be-30y-85m-avg-SWIR1.filled.lzw.nodata -0.14024930695692697
# Getting score for:  clim_EPA_albers -0.14058314760526022
# Getting score for:  be-30y-85m-avg-ND-SWIR1-SWIR2.filled.lzw.nodata -0.14036329090595245
# Getting score for:  relief_roughness -0.14038556814193726
# Getting score for:  si_geol1 -0.14100779592990875
# Getting score for:  be-30y-85m-avg-SWIR2.filled.lzw.nodata -0.14078588287035623
# Getting score for:  national_Wii_RF_multirandomforest_prediction -0.1404232382774353
# Getting score for:  3dem_mag2 -0.141330416003863
# Getting score for:  clim_WDA_albers -0.14038713773091635
# Getting score for:  Dose_2016 -0.14040897289911905
# Getting score for:  be-30y-85m-avg-GREEN.filled.lzw.nodata -0.1401782731215159
# Getting score for:  be-30y-85m-avg-CLAY-PC2.filled.lzw.nodata -0.14030243953069052
# Getting score for:  Clim_Prescott_LindaGregory -0.1405862420797348
# Getting score for:  Potassium_2016 -0.1408912092447281
# Getting score for:  mrvbf_9 -0.14070274432500204
# Getting score for:  Rad2016K_Th -0.14058141907056174
# Getting score for:  be-30y-85m-avg-ND-NIR-GREEN.filled.lzw.nodata -0.14094393452008566
# Getting score for:  be-l8-all-85m-avg-NIR.filled.lzw.nodata -0.14047007262706757
# Getting score for:  be-30y-85m-avg-RED.filled.lzw.nodata -0.13987024128437042
# Getting score for:  slope_fill2 -0.14032870531082153
# Getting score for:  clim_RSM_albers -0.1409336527188619
# Getting score for:  relief_elev_focalrange300m_3s -0.1406592826048533
# Getting score for:  relief_mrvbf_3s_mosaic -0.1406484693288803
# Getting score for:  Rad2016U_Th -0.14013606309890747
# Getting score for:  3dem_mag0.fin -0.14030915995438895
# Getting score for:  s2-dpca-85m_1 -0.14055684705575308
# Getting score for:  s2-dpca-85m_2 -0.14011371632417044
# Getting score for:  s2-dpca-85m_3 -0.1404801905155182
# Getting score for:  water-85m_1 -0.14054758350054422
# Getting score for:  water-85m_2 -0.1400489111741384
# Getting score for:  water-85m_3 -0.14029028018315634
# Getting score for:  saga_wetSM_85_reprojected -0.1406322419643402
# Results of  2  iteration: -0.14237058659394583
# Staring experiment for:  45
# Getting score for:  tpi_300 -0.14220981299877167
# Getting score for:  Grav_lane_clip -0.1427079290151596
# Getting score for:  clim_PTA_albers -0.14322405060132345
# Getting score for:  be-30y-85m-avg-ND-RED-BLUE.filled.lzw.nodata -0.14235620200634003
# Getting score for:  be-30y-85m-avg_BLUE+SWIR2 -0.1422850787639618
# Getting score for:  3dem_mag1_fin -0.1423084239164988
# Getting score for:  ceno_euc_aust1 -0.14229103922843933
# Getting score for:  be-l8-all-85m-avg-BLUE.filled.lzw.nodata -0.1419676293929418
# Getting score for:  be-30y-85m-avg-ND-SWIR1-NIR.filled.lzw.nodata -0.14251622557640076
# Getting score for:  Thorium_2016 -0.1419756362835566
# Getting score for:  relief_elev_focalrange1000m_3s -0.14256022373835245
# Getting score for:  LATITUDE_GRID1_clip -0.14363882939020792
# Getting score for:  LOC_distance_to_coast -0.14439332485198975
# Getting score for:  be-30y-85m-avg-SWIR1.filled.lzw.nodata -0.1420636127392451
# Getting score for:  clim_EPA_albers -0.1425410360097885
# Getting score for:  be-30y-85m-avg-ND-SWIR1-SWIR2.filled.lzw.nodata -0.14261911809444427
# Getting score for:  relief_roughness -0.14209544161955515
# Getting score for:  si_geol1 -0.14278757572174072
# Getting score for:  be-30y-85m-avg-SWIR2.filled.lzw.nodata -0.14218054711818695
# Getting score for:  national_Wii_RF_multirandomforest_prediction -0.14211606979370117
# Getting score for:  3dem_mag2 -0.14358222981293997
# Getting score for:  clim_WDA_albers -0.14243432382742563
# Getting score for:  Dose_2016 -0.1425491472085317
# Getting score for:  be-30y-85m-avg-GREEN.filled.lzw.nodata -0.14210313061873117
# Getting score for:  be-30y-85m-avg-CLAY-PC2.filled.lzw.nodata -0.14235246181488037
# Getting score for:  Clim_Prescott_LindaGregory -0.14347799122333527
# Getting score for:  Potassium_2016 -0.1425332377354304
# Getting score for:  mrvbf_9 -0.14276435474554697
# Getting score for:  Rad2016K_Th -0.14235465228557587
# Getting score for:  be-30y-85m-avg-ND-NIR-GREEN.filled.lzw.nodata -0.1427667240301768
# Getting score for:  be-l8-all-85m-avg-NIR.filled.lzw.nodata -0.14266579349835715
# Getting score for:  be-30y-85m-avg-RED.filled.lzw.nodata -0.14181821048259735
# Getting score for:  slope_fill2 -0.1423701991637548
# Getting score for:  clim_RSM_albers -0.1428275058666865
# Getting score for:  relief_elev_focalrange300m_3s -0.1424004981915156
# Getting score for:  relief_mrvbf_3s_mosaic -0.14205529789129892
# Getting score for:  Rad2016U_Th -0.14195692539215088
# Getting score for:  3dem_mag0.fin -0.14207063615322113
# Getting score for:  s2-dpca-85m_1 -0.14241290589173636
# Getting score for:  s2-dpca-85m_2 -0.14187001685301462
# Getting score for:  s2-dpca-85m_3 -0.1422328551610311
# Getting score for:  water-85m_1 -0.1424454003572464
# Getting score for:  water-85m_2 -0.14207210640112558
# Getting score for:  water-85m_3 -0.14206513265768686
# Getting score for:  saga_wetSM_85_reprojected -0.14191106955210367
# Results of  3  iteration: -0.14439332485198975
# Staring experiment for:  44
# Getting score for:  tpi_300 -0.14470933377742767
# Getting score for:  Grav_lane_clip -0.1455357720454534
# Getting score for:  clim_PTA_albers -0.145056222875913
# Getting score for:  be-30y-85m-avg-ND-RED-BLUE.filled.lzw.nodata -0.14512657125790915
# Getting score for:  be-30y-85m-avg_BLUE+SWIR2 -0.14479275047779083
# Getting score for:  3dem_mag1_fin -0.14500650763511658
# Getting score for:  ceno_euc_aust1 -0.14485503236452738
# Getting score for:  be-l8-all-85m-avg-BLUE.filled.lzw.nodata -0.1442768226067225
# Getting score for:  be-30y-85m-avg-ND-SWIR1-NIR.filled.lzw.nodata -0.14455677072207132
# Getting score for:  Thorium_2016 -0.1448730230331421
# Getting score for:  relief_elev_focalrange1000m_3s -0.14469391107559204
# Getting score for:  LATITUDE_GRID1_clip -0.14697368443012238
# Getting score for:  be-30y-85m-avg-SWIR1.filled.lzw.nodata -0.14429405828317007
# Getting score for:  clim_EPA_albers -0.1445765197277069
# Getting score for:  be-30y-85m-avg-ND-SWIR1-SWIR2.filled.lzw.nodata -0.14499767621358237
# Getting score for:  relief_roughness -0.1448596864938736
# Getting score for:  si_geol1 -0.1455768644809723
# Getting score for:  be-30y-85m-avg-SWIR2.filled.lzw.nodata -0.144832173983256
# Getting score for:  national_Wii_RF_multirandomforest_prediction -0.1447311689456304
# Getting score for:  3dem_mag2 -0.14628581702709198
# Getting score for:  clim_WDA_albers -0.14489937822024027
# Getting score for:  Dose_2016 -0.1447954773902893
# Getting score for:  be-30y-85m-avg-GREEN.filled.lzw.nodata -0.14473285774389902
# Getting score for:  be-30y-85m-avg-CLAY-PC2.filled.lzw.nodata -0.1441219002008438
# Getting score for:  Clim_Prescott_LindaGregory -0.14622477193673453
# Getting score for:  Potassium_2016 -0.14534859855969748
# Getting score for:  mrvbf_9 -0.1449067989985148
# Getting score for:  Rad2016K_Th -0.14501628776391348
# Getting score for:  be-30y-85m-avg-ND-NIR-GREEN.filled.lzw.nodata -0.14501878122488657
# Getting score for:  be-l8-all-85m-avg-NIR.filled.lzw.nodata -0.1447326342264811
# Getting score for:  be-30y-85m-avg-RED.filled.lzw.nodata -0.1446127692858378
# Getting score for:  slope_fill2 -0.14443284769852957
# Getting score for:  clim_RSM_albers -0.14551178614298502
# Getting score for:  relief_elev_focalrange300m_3s -0.14481751124064127
# Getting score for:  relief_mrvbf_3s_mosaic -0.14436685542265573
# Getting score for:  Rad2016U_Th -0.14461351931095123
# Getting score for:  3dem_mag0.fin -0.14448435107866922
# Getting score for:  s2-dpca-85m_1 -0.1448785662651062
# Getting score for:  s2-dpca-85m_2 -0.14454036951065063
# Getting score for:  s2-dpca-85m_3 -0.14450582365194956
# Getting score for:  water-85m_1 -0.14444349706172943
# Getting score for:  water-85m_2 -0.14407384395599365
# Getting score for:  water-85m_3 -0.14460930228233337
# Getting score for:  saga_wetSM_85_reprojected -0.1445464293162028
# Results of  4  iteration: -0.14697368443012238
# Staring experiment for:  43
# Getting score for:  tpi_300 -0.14739590883255005
# Getting score for:  Grav_lane_clip -0.14851472278436026
# Getting score for:  clim_PTA_albers -0.14913306136926016
# Getting score for:  be-30y-85m-avg-ND-RED-BLUE.filled.lzw.nodata -0.1478778918584188
# Getting score for:  be-30y-85m-avg_BLUE+SWIR2 -0.14709539214769998
# Getting score for:  3dem_mag1_fin -0.1480902632077535
# Getting score for:  ceno_euc_aust1 -0.14826448261737823
# Getting score for:  be-l8-all-85m-avg-BLUE.filled.lzw.nodata -0.14690380295117697
# Getting score for:  be-30y-85m-avg-ND-SWIR1-NIR.filled.lzw.nodata -0.14702381193637848
# Getting score for:  Thorium_2016 -0.1474500149488449
# Getting score for:  relief_elev_focalrange1000m_3s -0.14748425781726837
# Getting score for:  be-30y-85m-avg-SWIR1.filled.lzw.nodata -0.1475658416748047
# Getting score for:  clim_EPA_albers -0.14752404391765594
# Getting score for:  be-30y-85m-avg-ND-SWIR1-SWIR2.filled.lzw.nodata -0.1481139063835144
# Getting score for:  relief_roughness -0.1472075879573822
# Getting score for:  si_geol1 -0.14870768785476685
# Getting score for:  be-30y-85m-avg-SWIR2.filled.lzw.nodata -0.147152841091156
# Getting score for:  national_Wii_RF_multirandomforest_prediction -0.14718393981456757
# Getting score for:  3dem_mag2 -0.14899488786856332
# Getting score for:  clim_WDA_albers -0.1483968049287796
# Getting score for:  Dose_2016 -0.14669940869013467
# Getting score for:  be-30y-85m-avg-GREEN.filled.lzw.nodata -0.14742240806420645
# Getting score for:  be-30y-85m-avg-CLAY-PC2.filled.lzw.nodata -0.1472450147072474
# Getting score for:  Clim_Prescott_LindaGregory -0.14996361235777536
# Getting score for:  Potassium_2016 -0.14745326340198517
# Getting score for:  mrvbf_9 -0.14778011540571848
# Getting score for:  Rad2016K_Th -0.14763843019803366
# Getting score for:  be-30y-85m-avg-ND-NIR-GREEN.filled.lzw.nodata -0.14839776853720346
# Getting score for:  be-l8-all-85m-avg-NIR.filled.lzw.nodata -0.14728249112764993
# Getting score for:  be-30y-85m-avg-RED.filled.lzw.nodata -0.14745989441871643
# Getting score for:  slope_fill2 -0.14740076661109924
# Getting score for:  clim_RSM_albers -0.14862892031669617
# Getting score for:  relief_elev_focalrange300m_3s -0.14735199014345804
# Getting score for:  relief_mrvbf_3s_mosaic -0.1480671465396881
# Getting score for:  Rad2016U_Th -0.14675752321879068
# Getting score for:  3dem_mag0.fin -0.14705313742160797
# Getting score for:  s2-dpca-85m_1 -0.14739762743314108
# Getting score for:  s2-dpca-85m_2 -0.1469458838303884
# Getting score for:  s2-dpca-85m_3 -0.14703250924746195
# Getting score for:  water-85m_1 -0.14741899569829306
# Getting score for:  water-85m_2 -0.14740469058354697
# Getting score for:  water-85m_3 -0.14739746848742166
# Getting score for:  saga_wetSM_85_reprojected -0.14735067387421927
# Results of  5  iteration: -0.14996361235777536
# Staring experiment for:  42
# Getting score for:  tpi_300 -0.15018802881240845
# Getting score for:  Grav_lane_clip -0.15143642822901407
# Getting score for:  clim_PTA_albers -0.153416708111763
# Getting score for:  be-30y-85m-avg-ND-RED-BLUE.filled.lzw.nodata -0.15019710858662924
# Getting score for:  be-30y-85m-avg_BLUE+SWIR2 -0.15026464561621347
# Getting score for:  3dem_mag1_fin -0.15041006604830423
# Getting score for:  ceno_euc_aust1 -0.15051274498303732
# Getting score for:  be-l8-all-85m-avg-BLUE.filled.lzw.nodata -0.14964540799458823
# Getting score for:  be-30y-85m-avg-ND-SWIR1-NIR.filled.lzw.nodata -0.14993549386660257
# Getting score for:  Thorium_2016 -0.15035230418046316
# Getting score for:  relief_elev_focalrange1000m_3s -0.15068786342938742
# Getting score for:  be-30y-85m-avg-SWIR1.filled.lzw.nodata -0.15014218787352243
# Getting score for:  clim_EPA_albers -0.1499131272236506
# Getting score for:  be-30y-85m-avg-ND-SWIR1-SWIR2.filled.lzw.nodata -0.15030947824319205
# Getting score for:  relief_roughness -0.14991335570812225
# Getting score for:  si_geol1 -0.15177187820275626
# Getting score for:  be-30y-85m-avg-SWIR2.filled.lzw.nodata -0.15007606148719788
# Getting score for:  national_Wii_RF_multirandomforest_prediction -0.1498433401187261
# Getting score for:  3dem_mag2 -0.1521206647157669
# Getting score for:  clim_WDA_albers -0.15057179828484854
# Getting score for:  Dose_2016 -0.1499662697315216
# Getting score for:  be-30y-85m-avg-GREEN.filled.lzw.nodata -0.15003337959448496
# Getting score for:  be-30y-85m-avg-CLAY-PC2.filled.lzw.nodata -0.14959601561228433
# Getting score for:  Potassium_2016 -0.15033585826555887
# Getting score for:  mrvbf_9 -0.15037127335866293
# Getting score for:  Rad2016K_Th -0.1503373235464096
# Getting score for:  be-30y-85m-avg-ND-NIR-GREEN.filled.lzw.nodata -0.15153523286183676
# Getting score for:  be-l8-all-85m-avg-NIR.filled.lzw.nodata -0.14925692975521088
# Getting score for:  be-30y-85m-avg-RED.filled.lzw.nodata -0.1499992956717809
# Getting score for:  slope_fill2 -0.14996747175852457
# Getting score for:  clim_RSM_albers -0.15208248297373453
# Getting score for:  relief_elev_focalrange300m_3s -0.1498023271560669
# Getting score for:  relief_mrvbf_3s_mosaic -0.1503834674755732
# Getting score for:  Rad2016U_Th -0.14988839129606882
# Getting score for:  3dem_mag0.fin -0.1503563473622004
# Getting score for:  s2-dpca-85m_1 -0.15021173159281412
# Getting score for:  s2-dpca-85m_2 -0.15015433231989542
# Getting score for:  s2-dpca-85m_3 -0.149820014834404
# Getting score for:  water-85m_1 -0.1500972112019857
# Getting score for:  water-85m_2 -0.15024621287981668
# Getting score for:  water-85m_3 -0.15000357230504355
# Getting score for:  saga_wetSM_85_reprojected -0.1500282883644104
# Results of  6  iteration: -0.153416708111763
# Staring experiment for:  41
# Getting score for:  tpi_300 -0.15302558739980063
# Getting score for:  Grav_lane_clip -0.15429536998271942
# Getting score for:  be-30y-85m-avg-ND-RED-BLUE.filled.lzw.nodata -0.15325172245502472
# Getting score for:  be-30y-85m-avg_BLUE+SWIR2 -0.15310107668240866
# Getting score for:  3dem_mag1_fin -0.15374095737934113
# Getting score for:  ceno_euc_aust1 -0.15393700699011484
# Getting score for:  be-l8-all-85m-avg-BLUE.filled.lzw.nodata -0.1524296005566915
# Getting score for:  be-30y-85m-avg-ND-SWIR1-NIR.filled.lzw.nodata -0.1529094080130259
# Getting score for:  Thorium_2016 -0.15286454558372498
# Getting score for:  relief_elev_focalrange1000m_3s -0.15374622742335
# Getting score for:  be-30y-85m-avg-SWIR1.filled.lzw.nodata -0.15342317521572113
# Getting score for:  clim_EPA_albers -0.1548772950967153
# Getting score for:  be-30y-85m-avg-ND-SWIR1-SWIR2.filled.lzw.nodata -0.1532652626434962
# Getting score for:  relief_roughness -0.1534564346075058
# Getting score for:  si_geol1 -0.15471111238002777
# Getting score for:  be-30y-85m-avg-SWIR2.filled.lzw.nodata -0.15327145655949911
# Getting score for:  national_Wii_RF_multirandomforest_prediction -0.1533531347910563
# Getting score for:  3dem_mag2 -0.15519130726655325
# Getting score for:  clim_WDA_albers -0.15440560380617777
# Getting score for:  Dose_2016 -0.15342006584008536
# Getting score for:  be-30y-85m-avg-GREEN.filled.lzw.nodata -0.15288850168387094
# Getting score for:  be-30y-85m-avg-CLAY-PC2.filled.lzw.nodata -0.15327404936154684
# Getting score for:  Potassium_2016 -0.15358291069666544
# Getting score for:  mrvbf_9 -0.1535823792219162
# Getting score for:  Rad2016K_Th -0.15355058511098227
# Getting score for:  be-30y-85m-avg-ND-NIR-GREEN.filled.lzw.nodata -0.15367289880911508
# Getting score for:  be-l8-all-85m-avg-NIR.filled.lzw.nodata -0.15277263025442758
# Getting score for:  be-30y-85m-avg-RED.filled.lzw.nodata -0.15303566555182138
# Getting score for:  slope_fill2 -0.1532455881436666
# Getting score for:  clim_RSM_albers -0.15492044389247894
# Getting score for:  relief_elev_focalrange300m_3s -0.1533570388952891
# Getting score for:  relief_mrvbf_3s_mosaic -0.1534672975540161
# Getting score for:  Rad2016U_Th -0.15273981293042502
# Getting score for:  3dem_mag0.fin -0.15316788852214813
# Getting score for:  s2-dpca-85m_1 -0.1529542456070582
# Getting score for:  s2-dpca-85m_2 -0.15305391450723013
# Getting score for:  s2-dpca-85m_3 -0.15268383920192719
# Getting score for:  water-85m_1 -0.15314829846223196
# Getting score for:  water-85m_2 -0.15300014118353525
# Getting score for:  water-85m_3 -0.15304174522558847
# Getting score for:  saga_wetSM_85_reprojected -0.1529598335425059
# Results of  7  iteration: -0.15519130726655325
# Staring experiment for:  40
# Getting score for:  tpi_300 -0.1551820089419683
# Getting score for:  Grav_lane_clip -0.15659289558728537
# Getting score for:  be-30y-85m-avg-ND-RED-BLUE.filled.lzw.nodata -0.15578854580720267
# Getting score for:  be-30y-85m-avg_BLUE+SWIR2 -0.15499989688396454
# Getting score for:  3dem_mag1_fin -0.15680419902006784
# Getting score for:  ceno_euc_aust1 -0.15595018366972604
# Getting score for:  be-l8-all-85m-avg-BLUE.filled.lzw.nodata -0.1552173693974813
# Getting score for:  be-30y-85m-avg-ND-SWIR1-NIR.filled.lzw.nodata -0.15522778034210205
# Getting score for:  Thorium_2016 -0.15527854363123575
# Getting score for:  relief_elev_focalrange1000m_3s -0.15540278951327005
# Getting score for:  be-30y-85m-avg-SWIR1.filled.lzw.nodata -0.1556584139664968
# Getting score for:  clim_EPA_albers -0.15743241707483926
# Getting score for:  be-30y-85m-avg-ND-SWIR1-SWIR2.filled.lzw.nodata -0.15579902132352194
# Getting score for:  relief_roughness -0.1552983820438385
# Getting score for:  si_geol1 -0.15792726973692575
# Getting score for:  be-30y-85m-avg-SWIR2.filled.lzw.nodata -0.15512521068255106
# Getting score for:  national_Wii_RF_multirandomforest_prediction -0.15527462462584177
# Getting score for:  clim_WDA_albers -0.1572758307059606
# Getting score for:  Dose_2016 -0.155126690864563
# Getting score for:  be-30y-85m-avg-GREEN.filled.lzw.nodata -0.1552004317442576
# Getting score for:  be-30y-85m-avg-CLAY-PC2.filled.lzw.nodata -0.1550740897655487
# Getting score for:  Potassium_2016 -0.1554818650086721
# Getting score for:  mrvbf_9 -0.15596184631188711
# Getting score for:  Rad2016K_Th -0.1557606359322866
# Getting score for:  be-30y-85m-avg-ND-NIR-GREEN.filled.lzw.nodata -0.1558675318956375
# Getting score for:  be-l8-all-85m-avg-NIR.filled.lzw.nodata -0.1548579086860021
# Getting score for:  be-30y-85m-avg-RED.filled.lzw.nodata -0.15490727623303732
# Getting score for:  slope_fill2 -0.155070627729098
# Getting score for:  clim_RSM_albers -0.1572608401377996
# Getting score for:  relief_elev_focalrange300m_3s -0.15497388442357382
# Getting score for:  relief_mrvbf_3s_mosaic -0.15497837960720062
# Getting score for:  Rad2016U_Th -0.15508248408635458
# Getting score for:  3dem_mag0.fin -0.1554390788078308
# Getting score for:  s2-dpca-85m_1 -0.15549531082312265
# Getting score for:  s2-dpca-85m_2 -0.15477071205774942
# Getting score for:  s2-dpca-85m_3 -0.15532388289769491
# Getting score for:  water-85m_1 -0.1552791198094686
# Getting score for:  water-85m_2 -0.1549927294254303
# Getting score for:  water-85m_3 -0.15505506098270416
# Getting score for:  saga_wetSM_85_reprojected -0.1550951600074768
# Results of  8  iteration: -0.15792726973692575
# Staring experiment for:  39
# Getting score for:  tpi_300 -0.15778995056947073
# Getting score for:  Grav_lane_clip -0.15956905484199524
# Getting score for:  be-30y-85m-avg-ND-RED-BLUE.filled.lzw.nodata -0.15798368056615195
# Getting score for:  be-30y-85m-avg_BLUE+SWIR2 -0.15729041894276938
# Getting score for:  3dem_mag1_fin -0.15966763099034628
# Getting score for:  ceno_euc_aust1 -0.1589776575565338
# Getting score for:  be-l8-all-85m-avg-BLUE.filled.lzw.nodata -0.15747407575448355
# Getting score for:  be-30y-85m-avg-ND-SWIR1-NIR.filled.lzw.nodata -0.15749127169450125
# Getting score for:  Thorium_2016 -0.1575196236371994
# Getting score for:  relief_elev_focalrange1000m_3s -0.15782561401526132
# Getting score for:  be-30y-85m-avg-SWIR1.filled.lzw.nodata -0.15760830541451773
# Getting score for:  clim_EPA_albers -0.16005982955296835
# Getting score for:  be-30y-85m-avg-ND-SWIR1-SWIR2.filled.lzw.nodata -0.15805610517660776
# Getting score for:  relief_roughness -0.15765759348869324
# Getting score for:  be-30y-85m-avg-SWIR2.filled.lzw.nodata -0.15755275388558707
# Getting score for:  national_Wii_RF_multirandomforest_prediction -0.15783938268820444
# Getting score for:  clim_WDA_albers -0.15956524511178335
# Getting score for:  Dose_2016 -0.15759144723415375
# Getting score for:  be-30y-85m-avg-GREEN.filled.lzw.nodata -0.1574868013461431
# Getting score for:  be-30y-85m-avg-CLAY-PC2.filled.lzw.nodata -0.15773992240428925
# Getting score for:  Potassium_2016 -0.15792183081309
# Getting score for:  mrvbf_9 -0.15836156904697418
# Getting score for:  Rad2016K_Th -0.15755618115266165
# Getting score for:  be-30y-85m-avg-ND-NIR-GREEN.filled.lzw.nodata -0.15813535948594412
# Getting score for:  be-l8-all-85m-avg-NIR.filled.lzw.nodata -0.15762050449848175
# Getting score for:  be-30y-85m-avg-RED.filled.lzw.nodata -0.15767506758371988
# Getting score for:  slope_fill2 -0.15759533643722534
# Getting score for:  clim_RSM_albers -0.15974904596805573
# Getting score for:  relief_elev_focalrange300m_3s -0.1576621731122335
# Getting score for:  relief_mrvbf_3s_mosaic -0.157816082239151
# Getting score for:  Rad2016U_Th -0.15709595382213593
# Getting score for:  3dem_mag0.fin -0.157599205772082
# Getting score for:  s2-dpca-85m_1 -0.15760380029678345
# Getting score for:  s2-dpca-85m_2 -0.15784446895122528
# Getting score for:  s2-dpca-85m_3 -0.1572375496228536
# Getting score for:  water-85m_1 -0.15751111507415771
# Getting score for:  water-85m_2 -0.15781961878140768
# Getting score for:  water-85m_3 -0.1573317845662435
# Getting score for:  saga_wetSM_85_reprojected -0.1577644795179367
# Results of  9  iteration: -0.16005982955296835
# Staring experiment for:  38
# Getting score for:  tpi_300 -0.16011575361092886
# Getting score for:  Grav_lane_clip -0.16281582911809286
# Getting score for:  be-30y-85m-avg-ND-RED-BLUE.filled.lzw.nodata -0.16140882670879364
# Getting score for:  be-30y-85m-avg_BLUE+SWIR2 -0.16024366517861685
# Getting score for:  3dem_mag1_fin -0.16284688313802084
# Getting score for:  ceno_euc_aust1 -0.16177093982696533
# Getting score for:  be-l8-all-85m-avg-BLUE.filled.lzw.nodata -0.1599176526069641
# Getting score for:  be-30y-85m-avg-ND-SWIR1-NIR.filled.lzw.nodata -0.16102932890256247
# Getting score for:  Thorium_2016 -0.16044710079828897
# Getting score for:  relief_elev_focalrange1000m_3s -0.16046430667241415
# Getting score for:  be-30y-85m-avg-SWIR1.filled.lzw.nodata -0.16080186267693838
# Getting score for:  be-30y-85m-avg-ND-SWIR1-SWIR2.filled.lzw.nodata -0.16089327136675516
# Getting score for:  relief_roughness -0.16031324863433838
# Getting score for:  be-30y-85m-avg-SWIR2.filled.lzw.nodata -0.16071975231170654
# Getting score for:  national_Wii_RF_multirandomforest_prediction -0.1603520611921946
# Getting score for:  clim_WDA_albers -0.16289914647738138
# Getting score for:  Dose_2016 -0.16053512195746103
# Getting score for:  be-30y-85m-avg-GREEN.filled.lzw.nodata -0.15988730390866598
# Getting score for:  be-30y-85m-avg-CLAY-PC2.filled.lzw.nodata -0.16032622257868448
# Getting score for:  Potassium_2016 -0.16116595268249512
# Getting score for:  mrvbf_9 -0.1612921009461085
# Getting score for:  Rad2016K_Th -0.16046196222305298
# Getting score for:  be-30y-85m-avg-ND-NIR-GREEN.filled.lzw.nodata -0.1611425777276357
# Getting score for:  be-l8-all-85m-avg-NIR.filled.lzw.nodata -0.1605861335992813
# Getting score for:  be-30y-85m-avg-RED.filled.lzw.nodata -0.16032300889492035
# Getting score for:  slope_fill2 -0.1602388173341751
# Getting score for:  clim_RSM_albers -0.16399291157722473
# Getting score for:  relief_elev_focalrange300m_3s -0.16018393635749817
# Getting score for:  relief_mrvbf_3s_mosaic -0.16058823466300964
# Getting score for:  Rad2016U_Th -0.1602091540892919
# Getting score for:  3dem_mag0.fin -0.1609007865190506
# Getting score for:  s2-dpca-85m_1 -0.16040862600008646
# Getting score for:  s2-dpca-85m_2 -0.16082817316055298
# Getting score for:  s2-dpca-85m_3 -0.1602919101715088
# Getting score for:  water-85m_1 -0.16074709594249725
# Getting score for:  water-85m_2 -0.16045377651850382
# Getting score for:  water-85m_3 -0.16002383331457773
# Getting score for:  saga_wetSM_85_reprojected -0.16063903272151947
# Results of  10  iteration: -0.16399291157722473
# Staring experiment for:  37
# Getting score for:  tpi_300 -0.1639444281657537
# Getting score for:  Grav_lane_clip -0.16704406837622324
# Getting score for:  be-30y-85m-avg-ND-RED-BLUE.filled.lzw.nodata -0.1648472249507904
# Getting score for:  be-30y-85m-avg_BLUE+SWIR2 -0.16439926624298096
# Getting score for:  3dem_mag1_fin -0.1666287233432134
# Getting score for:  ceno_euc_aust1 -0.16585048536459604
# Getting score for:  be-l8-all-85m-avg-BLUE.filled.lzw.nodata -0.1635796328385671
# Getting score for:  be-30y-85m-avg-ND-SWIR1-NIR.filled.lzw.nodata -0.1640676607688268
# Getting score for:  Thorium_2016 -0.16431349515914917
# Getting score for:  relief_elev_focalrange1000m_3s -0.16423330207665762
# Getting score for:  be-30y-85m-avg-SWIR1.filled.lzw.nodata -0.1639178842306137
# Getting score for:  be-30y-85m-avg-ND-SWIR1-SWIR2.filled.lzw.nodata -0.16503296792507172
# Getting score for:  relief_roughness -0.1642477810382843
# Getting score for:  be-30y-85m-avg-SWIR2.filled.lzw.nodata -0.1637462576230367
# Getting score for:  national_Wii_RF_multirandomforest_prediction -0.163899893561999
# Getting score for:  clim_WDA_albers -0.16695865988731384
# Getting score for:  Dose_2016 -0.1642465442419052
# Getting score for:  be-30y-85m-avg-GREEN.filled.lzw.nodata -0.16424140830834708
# Getting score for:  be-30y-85m-avg-CLAY-PC2.filled.lzw.nodata -0.16425912082195282
# Getting score for:  Potassium_2016 -0.16456998884677887
# Getting score for:  mrvbf_9 -0.16479450464248657
# Getting score for:  Rad2016K_Th -0.16439802447954813
# Getting score for:  be-30y-85m-avg-ND-NIR-GREEN.filled.lzw.nodata -0.16487781703472137
# Getting score for:  be-l8-all-85m-avg-NIR.filled.lzw.nodata -0.16399296124776205
# Getting score for:  be-30y-85m-avg-RED.filled.lzw.nodata -0.16434814035892487
# Getting score for:  slope_fill2 -0.16416804989178976
# Getting score for:  relief_elev_focalrange300m_3s -0.16367214421431223
# Getting score for:  relief_mrvbf_3s_mosaic -0.16455399990081787
# Getting score for:  Rad2016U_Th -0.16406718889872232
# Getting score for:  3dem_mag0.fin -0.16448407371838888
# Getting score for:  s2-dpca-85m_1 -0.16418382028738657
# Getting score for:  s2-dpca-85m_2 -0.16421111424763998
# Getting score for:  s2-dpca-85m_3 -0.16409887373447418
# Getting score for:  water-85m_1 -0.16480881969134012
# Getting score for:  water-85m_2 -0.1641353170077006
# Getting score for:  water-85m_3 -0.1644863486289978
# Getting score for:  saga_wetSM_85_reprojected -0.1641165167093277
# Results of  11  iteration: -0.16704406837622324
# Staring experiment for:  36
# Getting score for:  tpi_300 -0.16701286534468332
# Getting score for:  be-30y-85m-avg-ND-RED-BLUE.filled.lzw.nodata -0.16745290656884512
# Getting score for:  be-30y-85m-avg_BLUE+SWIR2 -0.16723158458868662
# Getting score for:  3dem_mag1_fin -0.16928570965925852
# Getting score for:  ceno_euc_aust1 -0.1688298135995865
# Getting score for:  be-l8-all-85m-avg-BLUE.filled.lzw.nodata -0.1666213721036911
# Getting score for:  be-30y-85m-avg-ND-SWIR1-NIR.filled.lzw.nodata -0.16729116439819336
# Getting score for:  Thorium_2016 -0.1670331060886383
# Getting score for:  relief_elev_focalrange1000m_3s -0.16775439182917276
# Getting score for:  be-30y-85m-avg-SWIR1.filled.lzw.nodata -0.16675680379072824
# Getting score for:  be-30y-85m-avg-ND-SWIR1-SWIR2.filled.lzw.nodata -0.16770114998022714
# Getting score for:  relief_roughness -0.16668018201986948
# Getting score for:  be-30y-85m-avg-SWIR2.filled.lzw.nodata -0.16701876123746237
# Getting score for:  national_Wii_RF_multirandomforest_prediction -0.1673419028520584
# Getting score for:  clim_WDA_albers -0.1701766401529312
# Getting score for:  Dose_2016 -0.1671899606784185
# Getting score for:  be-30y-85m-avg-GREEN.filled.lzw.nodata -0.16699830691019693
# Getting score for:  be-30y-85m-avg-CLAY-PC2.filled.lzw.nodata -0.16687174141407013
# Getting score for:  Potassium_2016 -0.16727655132611594
# Getting score for:  mrvbf_9 -0.1681191325187683
# Getting score for:  Rad2016K_Th -0.16762094696362814
# Getting score for:  be-30y-85m-avg-ND-NIR-GREEN.filled.lzw.nodata -0.16768557329972586
# Getting score for:  be-l8-all-85m-avg-NIR.filled.lzw.nodata -0.16743201514085135
# Getting score for:  be-30y-85m-avg-RED.filled.lzw.nodata -0.16700749595959982
# Getting score for:  slope_fill2 -0.16695807874202728
# Getting score for:  relief_elev_focalrange300m_3s -0.16715388496716818
# Getting score for:  relief_mrvbf_3s_mosaic -0.16717867056528726
# Getting score for:  Rad2016U_Th -0.16681166489919028
# Getting score for:  3dem_mag0.fin -0.16700531045595804
# Getting score for:  s2-dpca-85m_1 -0.16732735435167947
# Getting score for:  s2-dpca-85m_2 -0.16691449284553528
# Getting score for:  s2-dpca-85m_3 -0.16702978312969208
# Getting score for:  water-85m_1 -0.16725793977578482
# Getting score for:  water-85m_2 -0.166941170891126
# Getting score for:  water-85m_3 -0.16718160609404245
# Getting score for:  saga_wetSM_85_reprojected -0.16709374884764353
# Results of  12  iteration: -0.1701766401529312
# Staring experiment for:  35
# Getting score for:  tpi_300 -0.17035221556822458
# Getting score for:  be-30y-85m-avg-ND-RED-BLUE.filled.lzw.nodata -0.17136898636817932
# Getting score for:  be-30y-85m-avg_BLUE+SWIR2 -0.1705260823170344
# Getting score for:  3dem_mag1_fin -0.1733620564142863
# Getting score for:  ceno_euc_aust1 -0.17240881423155466
# Getting score for:  be-l8-all-85m-avg-BLUE.filled.lzw.nodata -0.1703415165344874
# Getting score for:  be-30y-85m-avg-ND-SWIR1-NIR.filled.lzw.nodata -0.1704824318488439
# Getting score for:  Thorium_2016 -0.17077822983264923
# Getting score for:  relief_elev_focalrange1000m_3s -0.17103077471256256
# Getting score for:  be-30y-85m-avg-SWIR1.filled.lzw.nodata -0.17056828240553537
# Getting score for:  be-30y-85m-avg-ND-SWIR1-SWIR2.filled.lzw.nodata -0.17104410628477731
# Getting score for:  relief_roughness -0.17048012216885886
# Getting score for:  be-30y-85m-avg-SWIR2.filled.lzw.nodata -0.17075245579083762
# Getting score for:  national_Wii_RF_multirandomforest_prediction -0.17064741750558218
# Getting score for:  Dose_2016 -0.1709015667438507
# Getting score for:  be-30y-85m-avg-GREEN.filled.lzw.nodata -0.1708206832408905
# Getting score for:  be-30y-85m-avg-CLAY-PC2.filled.lzw.nodata -0.17054963111877441
# Getting score for:  Potassium_2016 -0.17118602494398752
# Getting score for:  mrvbf_9 -0.17156539857387543
# Getting score for:  Rad2016K_Th -0.1706383874018987
# Getting score for:  be-30y-85m-avg-ND-NIR-GREEN.filled.lzw.nodata -0.17124202847480774
# Getting score for:  be-l8-all-85m-avg-NIR.filled.lzw.nodata -0.17032893498738608
# Getting score for:  be-30y-85m-avg-RED.filled.lzw.nodata -0.17051448424657187
# Getting score for:  slope_fill2 -0.1703042189280192
# Getting score for:  relief_elev_focalrange300m_3s -0.17002122600873312
# Getting score for:  relief_mrvbf_3s_mosaic -0.17111838360627493
# Getting score for:  Rad2016U_Th -0.17034042378266653
# Getting score for:  3dem_mag0.fin -0.17022534211476645
# Getting score for:  s2-dpca-85m_1 -0.17071000734965006
# Getting score for:  s2-dpca-85m_2 -0.170562873284022
# Getting score for:  s2-dpca-85m_3 -0.1707242727279663
# Getting score for:  water-85m_1 -0.17119005819161734
# Getting score for:  water-85m_2 -0.17040623724460602
# Getting score for:  water-85m_3 -0.17039871712525687
# Getting score for:  saga_wetSM_85_reprojected -0.17087753117084503
# Results of  13  iteration: -0.1733620564142863
# Staring experiment for:  34
# Getting score for:  tpi_300 -0.17325598994890848
# Getting score for:  be-30y-85m-avg-ND-RED-BLUE.filled.lzw.nodata -0.17437400420506796
# Getting score for:  be-30y-85m-avg_BLUE+SWIR2 -0.17321219046910605
# Getting score for:  ceno_euc_aust1 -0.17489461104075113
# Getting score for:  be-l8-all-85m-avg-BLUE.filled.lzw.nodata -0.17340217034022012
# Getting score for:  be-30y-85m-avg-ND-SWIR1-NIR.filled.lzw.nodata -0.17381085455417633
# Getting score for:  Thorium_2016 -0.17366652687390646
# Getting score for:  relief_elev_focalrange1000m_3s -0.17412925759951273
# Getting score for:  be-30y-85m-avg-SWIR1.filled.lzw.nodata -0.17334258556365967
# Getting score for:  be-30y-85m-avg-ND-SWIR1-SWIR2.filled.lzw.nodata -0.17413654923439026
# Getting score for:  relief_roughness -0.1728634536266327
# Getting score for:  be-30y-85m-avg-SWIR2.filled.lzw.nodata -0.17319093147913614
# Getting score for:  national_Wii_RF_multirandomforest_prediction -0.17336453994115195
# Getting score for:  Dose_2016 -0.17348762353261313
# Getting score for:  be-30y-85m-avg-GREEN.filled.lzw.nodata -0.17328152557214102
# Getting score for:  be-30y-85m-avg-CLAY-PC2.filled.lzw.nodata -0.17344145476818085
# Getting score for:  Potassium_2016 -0.17391223212083182
# Getting score for:  mrvbf_9 -0.1752415100733439
# Getting score for:  Rad2016K_Th -0.17371381322542825
# Getting score for:  be-30y-85m-avg-ND-NIR-GREEN.filled.lzw.nodata -0.17422043780485788
# Getting score for:  be-l8-all-85m-avg-NIR.filled.lzw.nodata -0.1729076753060023
# Getting score for:  be-30y-85m-avg-RED.filled.lzw.nodata -0.17300068338712057
# Getting score for:  slope_fill2 -0.17321345210075378
# Getting score for:  relief_elev_focalrange300m_3s -0.17349751790364584
# Getting score for:  relief_mrvbf_3s_mosaic -0.17380377650260925
# Getting score for:  Rad2016U_Th -0.17334429919719696
# Getting score for:  3dem_mag0.fin -0.17351887126763663
# Getting score for:  s2-dpca-85m_1 -0.17385530471801758
# Getting score for:  s2-dpca-85m_2 -0.17379378775755563
# Getting score for:  s2-dpca-85m_3 -0.17343026399612427
# Getting score for:  water-85m_1 -0.17385550836722055
# Getting score for:  water-85m_2 -0.17316208283106485
# Getting score for:  water-85m_3 -0.1729208379983902
# Getting score for:  saga_wetSM_85_reprojected -0.17361332476139069
# Results of  14  iteration: -0.1752415100733439
# Staring experiment for:  33
# Getting score for:  tpi_300 -0.175205131371816
# Getting score for:  be-30y-85m-avg-ND-RED-BLUE.filled.lzw.nodata -0.17647680640220642
# Getting score for:  be-30y-85m-avg_BLUE+SWIR2 -0.17540882527828217
# Getting score for:  ceno_euc_aust1 -0.1770166208346685
# Getting score for:  be-l8-all-85m-avg-BLUE.filled.lzw.nodata -0.17504907647768655
# Getting score for:  be-30y-85m-avg-ND-SWIR1-NIR.filled.lzw.nodata -0.17565690477689108
# Getting score for:  Thorium_2016 -0.17556849122047424
# Getting score for:  relief_elev_focalrange1000m_3s -0.1759723275899887
# Getting score for:  be-30y-85m-avg-SWIR1.filled.lzw.nodata -0.17537060379981995
# Getting score for:  be-30y-85m-avg-ND-SWIR1-SWIR2.filled.lzw.nodata -0.17616836726665497
# Getting score for:  relief_roughness -0.17537464698155722
# Getting score for:  be-30y-85m-avg-SWIR2.filled.lzw.nodata -0.17516313989957175
# Getting score for:  national_Wii_RF_multirandomforest_prediction -0.17530196905136108
# Getting score for:  Dose_2016 -0.1756248672803243
# Getting score for:  be-30y-85m-avg-GREEN.filled.lzw.nodata -0.17523378630479178
# Getting score for:  be-30y-85m-avg-CLAY-PC2.filled.lzw.nodata -0.1751031130552292
# Getting score for:  Potassium_2016 -0.1760817915201187
# Getting score for:  Rad2016K_Th -0.1760519047578176
# Getting score for:  be-30y-85m-avg-ND-NIR-GREEN.filled.lzw.nodata -0.17623371382554373
# Getting score for:  be-l8-all-85m-avg-NIR.filled.lzw.nodata -0.17531421780586243
# Getting score for:  be-30y-85m-avg-RED.filled.lzw.nodata -0.17550858358542124
# Getting score for:  slope_fill2 -0.17552430927753448
# Getting score for:  relief_elev_focalrange300m_3s -0.17508567372957864
# Getting score for:  relief_mrvbf_3s_mosaic -0.1777477115392685
# Getting score for:  Rad2016U_Th -0.17529776195685068
# Getting score for:  3dem_mag0.fin -0.1759009708960851
# Getting score for:  s2-dpca-85m_1 -0.17535021901130676
# Getting score for:  s2-dpca-85m_2 -0.17582245667775473
# Getting score for:  s2-dpca-85m_3 -0.17563328643639883
# Getting score for:  water-85m_1 -0.17582056919733682
# Getting score for:  water-85m_2 -0.17521902918815613
# Getting score for:  water-85m_3 -0.17518331607182822
# Getting score for:  saga_wetSM_85_reprojected -0.1756004939476649
# Results of  15  iteration: -0.1777477115392685
# Staring experiment for:  32
# Getting score for:  tpi_300 -0.1775574584801992
# Getting score for:  be-30y-85m-avg-ND-RED-BLUE.filled.lzw.nodata -0.17879679799079895
# Getting score for:  be-30y-85m-avg_BLUE+SWIR2 -0.17758666475613913
# Getting score for:  ceno_euc_aust1 -0.17968109250068665
# Getting score for:  be-l8-all-85m-avg-BLUE.filled.lzw.nodata -0.17773295938968658
# Getting score for:  be-30y-85m-avg-ND-SWIR1-NIR.filled.lzw.nodata -0.17795600493748984
# Getting score for:  Thorium_2016 -0.1777848800023397
# Getting score for:  relief_elev_focalrange1000m_3s -0.17868519326051077
# Getting score for:  be-30y-85m-avg-SWIR1.filled.lzw.nodata -0.17759062349796295
# Getting score for:  be-30y-85m-avg-ND-SWIR1-SWIR2.filled.lzw.nodata -0.17846623559792837
# Getting score for:  relief_roughness -0.17756146689256033
# Getting score for:  be-30y-85m-avg-SWIR2.filled.lzw.nodata -0.17763464649518332
# Getting score for:  national_Wii_RF_multirandomforest_prediction -0.17776896059513092
# Getting score for:  Dose_2016 -0.17765597005685171
# Getting score for:  be-30y-85m-avg-GREEN.filled.lzw.nodata -0.17774304747581482
# Getting score for:  be-30y-85m-avg-CLAY-PC2.filled.lzw.nodata -0.17764165997505188
# Getting score for:  Potassium_2016 -0.17800256609916687
# Getting score for:  Rad2016K_Th -0.1778961718082428
# Getting score for:  be-30y-85m-avg-ND-NIR-GREEN.filled.lzw.nodata -0.17837514479955038
# Getting score for:  be-l8-all-85m-avg-NIR.filled.lzw.nodata -0.17763651410738626
# Getting score for:  be-30y-85m-avg-RED.filled.lzw.nodata -0.17738348742326102
# Getting score for:  slope_fill2 -0.17753001054128012
# Getting score for:  relief_elev_focalrange300m_3s -0.1775907576084137
# Getting score for:  Rad2016U_Th -0.17778116961320242
# Getting score for:  3dem_mag0.fin -0.1776074469089508
# Getting score for:  s2-dpca-85m_1 -0.1777476668357849
# Getting score for:  s2-dpca-85m_2 -0.17795555790265402
# Getting score for:  s2-dpca-85m_3 -0.17761128644148508
# Getting score for:  water-85m_1 -0.17830199003219604
# Getting score for:  water-85m_2 -0.17777573565642038
# Getting score for:  water-85m_3 -0.1777712603410085
# Getting score for:  saga_wetSM_85_reprojected -0.1779368668794632
# Results of  16  iteration: -0.17968109250068665
# Staring experiment for:  31
# Getting score for:  tpi_300 -0.17930524547894797
# Getting score for:  be-30y-85m-avg-ND-RED-BLUE.filled.lzw.nodata -0.18072440723578134
# Getting score for:  be-30y-85m-avg_BLUE+SWIR2 -0.17947167654832205
# Getting score for:  be-l8-all-85m-avg-BLUE.filled.lzw.nodata -0.17952718834082285
# Getting score for:  be-30y-85m-avg-ND-SWIR1-NIR.filled.lzw.nodata -0.17979172865549722
# Getting score for:  Thorium_2016 -0.17988109091917673
# Getting score for:  relief_elev_focalrange1000m_3s -0.18108992278575897
# Getting score for:  be-30y-85m-avg-SWIR1.filled.lzw.nodata -0.17954672376314798
# Getting score for:  be-30y-85m-avg-ND-SWIR1-SWIR2.filled.lzw.nodata -0.1801548550526301
# Getting score for:  relief_roughness -0.17926102379957834
# Getting score for:  be-30y-85m-avg-SWIR2.filled.lzw.nodata -0.17964349687099457
# Getting score for:  national_Wii_RF_multirandomforest_prediction -0.17978700498739877
# Getting score for:  Dose_2016 -0.17961081862449646
# Getting score for:  be-30y-85m-avg-GREEN.filled.lzw.nodata -0.1793785790602366
# Getting score for:  be-30y-85m-avg-CLAY-PC2.filled.lzw.nodata -0.17947258551915488
# Getting score for:  Potassium_2016 -0.18030725916226706
# Getting score for:  Rad2016K_Th -0.1800933082898458
# Getting score for:  be-30y-85m-avg-ND-NIR-GREEN.filled.lzw.nodata -0.18021864195664725
# Getting score for:  be-l8-all-85m-avg-NIR.filled.lzw.nodata -0.17971908549467722
# Getting score for:  be-30y-85m-avg-RED.filled.lzw.nodata -0.1797948678334554
# Getting score for:  slope_fill2 -0.17946758369604746
# Getting score for:  relief_elev_focalrange300m_3s -0.17952151596546173
# Getting score for:  Rad2016U_Th -0.17961286505063376
# Getting score for:  3dem_mag0.fin -0.17990532020727792
# Getting score for:  s2-dpca-85m_1 -0.17988774180412292
# Getting score for:  s2-dpca-85m_2 -0.17988034089406332
# Getting score for:  s2-dpca-85m_3 -0.1797036329905192
# Getting score for:  water-85m_1 -0.18022623658180237
# Getting score for:  water-85m_2 -0.17954862614472708
# Getting score for:  water-85m_3 -0.1795133799314499
# Getting score for:  saga_wetSM_85_reprojected -0.17987644175688425
# Results of  17  iteration: -0.18108992278575897
# Staring experiment for:  30
# Getting score for:  tpi_300 -0.1813006947437922
# Getting score for:  be-30y-85m-avg-ND-RED-BLUE.filled.lzw.nodata -0.1825368901093801
# Getting score for:  be-30y-85m-avg_BLUE+SWIR2 -0.18099049727121988
# Getting score for:  be-l8-all-85m-avg-BLUE.filled.lzw.nodata -0.1810807337363561
# Getting score for:  be-30y-85m-avg-ND-SWIR1-NIR.filled.lzw.nodata -0.18165325621763864
# Getting score for:  Thorium_2016 -0.1811773031949997
# Getting score for:  be-30y-85m-avg-SWIR1.filled.lzw.nodata -0.18104089299837747
# Getting score for:  be-30y-85m-avg-ND-SWIR1-SWIR2.filled.lzw.nodata -0.18218258023262024
# Getting score for:  relief_roughness -0.18114410837491354
# Getting score for:  be-30y-85m-avg-SWIR2.filled.lzw.nodata -0.18099923431873322
# Getting score for:  national_Wii_RF_multirandomforest_prediction -0.1817831297715505
# Getting score for:  Dose_2016 -0.18149287501970926
# Getting score for:  be-30y-85m-avg-GREEN.filled.lzw.nodata -0.18129082024097443
# Getting score for:  be-30y-85m-avg-CLAY-PC2.filled.lzw.nodata -0.18126414716243744
# Getting score for:  Potassium_2016 -0.18198136488596597
# Getting score for:  Rad2016K_Th -0.18177381654580435
# Getting score for:  be-30y-85m-avg-ND-NIR-GREEN.filled.lzw.nodata -0.1819092184305191
# Getting score for:  be-l8-all-85m-avg-NIR.filled.lzw.nodata -0.18120290835698447
# Getting score for:  be-30y-85m-avg-RED.filled.lzw.nodata -0.1810483088095983
# Getting score for:  slope_fill2 -0.1809403250614802
# Getting score for:  relief_elev_focalrange300m_3s -0.18145673970381418
# Getting score for:  Rad2016U_Th -0.18142967919508615
# Getting score for:  3dem_mag0.fin -0.1816745102405548
# Getting score for:  s2-dpca-85m_1 -0.1815771907567978
# Getting score for:  s2-dpca-85m_2 -0.18174072603384653
# Getting score for:  s2-dpca-85m_3 -0.18151447176933289
# Getting score for:  water-85m_1 -0.18182213604450226
# Getting score for:  water-85m_2 -0.18119202554225922
# Getting score for:  water-85m_3 -0.18105819821357727
# Getting score for:  saga_wetSM_85_reprojected -0.18229483564694723
# Results of  18  iteration: -0.1825368901093801
# Staring experiment for:  29
# Getting score for:  tpi_300 -0.18264072140057883
# Getting score for:  be-30y-85m-avg_BLUE+SWIR2 -0.1826330671707789
# Getting score for:  be-l8-all-85m-avg-BLUE.filled.lzw.nodata -0.18276263773441315
# Getting score for:  be-30y-85m-avg-ND-SWIR1-NIR.filled.lzw.nodata -0.1832121511300405
# Getting score for:  Thorium_2016 -0.18286240100860596
# Getting score for:  be-30y-85m-avg-SWIR1.filled.lzw.nodata -0.18263977766036987
# Getting score for:  be-30y-85m-avg-ND-SWIR1-SWIR2.filled.lzw.nodata -0.18372816344102225
# Getting score for:  relief_roughness -0.18236514429251352
# Getting score for:  be-30y-85m-avg-SWIR2.filled.lzw.nodata -0.1824945459763209
# Getting score for:  national_Wii_RF_multirandomforest_prediction -0.1830207109451294
# Getting score for:  Dose_2016 -0.18286083141962686
# Getting score for:  be-30y-85m-avg-GREEN.filled.lzw.nodata -0.18236210445562998
# Getting score for:  be-30y-85m-avg-CLAY-PC2.filled.lzw.nodata -0.18299037218093872
# Getting score for:  Potassium_2016 -0.18334569036960602
# Getting score for:  Rad2016K_Th -0.18324624001979828
# Getting score for:  be-30y-85m-avg-ND-NIR-GREEN.filled.lzw.nodata -0.1838229497273763
# Getting score for:  be-l8-all-85m-avg-NIR.filled.lzw.nodata -0.18288043638070425
# Getting score for:  be-30y-85m-avg-RED.filled.lzw.nodata -0.18300655980904898
# Getting score for:  slope_fill2 -0.18243800103664398
# Getting score for:  relief_elev_focalrange300m_3s -0.18297996123631796
# Getting score for:  Rad2016U_Th -0.18279307583967844
# Getting score for:  3dem_mag0.fin -0.1829486091931661
# Getting score for:  s2-dpca-85m_1 -0.18310239414374033
# Getting score for:  s2-dpca-85m_2 -0.18297031025091806
# Getting score for:  s2-dpca-85m_3 -0.1827693978945414
# Getting score for:  water-85m_1 -0.18344992895921072
# Getting score for:  water-85m_2 -0.1828312228123347
# Getting score for:  water-85m_3 -0.1827904929717382
# Getting score for:  saga_wetSM_85_reprojected -0.18372253080209097
# Results of  19  iteration: -0.1838229497273763
# Staring experiment for:  28
# Getting score for:  tpi_300 -0.18375816444555917
# Getting score for:  be-30y-85m-avg_BLUE+SWIR2 -0.18376985689004263
# Getting score for:  be-l8-all-85m-avg-BLUE.filled.lzw.nodata -0.1840845694144567
# Getting score for:  be-30y-85m-avg-ND-SWIR1-NIR.filled.lzw.nodata -0.18469980855782828
# Getting score for:  Thorium_2016 -0.1839345246553421
# Getting score for:  be-30y-85m-avg-SWIR1.filled.lzw.nodata -0.18380697071552277
# Getting score for:  be-30y-85m-avg-ND-SWIR1-SWIR2.filled.lzw.nodata -0.1851686785618464
# Getting score for:  relief_roughness -0.18372653921445212
# Getting score for:  be-30y-85m-avg-SWIR2.filled.lzw.nodata -0.1838004340728124
# Getting score for:  national_Wii_RF_multirandomforest_prediction -0.18432876467704773
# Getting score for:  Dose_2016 -0.18380893766880035

# %%
features_to_drop = 19
feature_to_drop_2 = []
for exp_id in results:
    max_score = 0
    for feature in custom_results[exp_id]:
        currect_score = custom_results[exp_id]["intermediate_results"][feature]
        if currect_score > max_score:
            max_score = currect_score
            lowest_feature = feature
    feature_to_drop_2.append(lowest_feature)
    if len(feature_to_drop_2) == features_to_drop:
        break
feature_to_drop_2

# %% [markdown]
# # Recursive feature elimination with cross-validation - sklearn

# %%
# %%time
from sklearn.model_selection import KFold
from xgboost import XGBRegressor
from sklearn.feature_selection import RFECV
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from pathlib import Path
import numpy as np
import pandas as pd

input_files = [
    Path("../data/formated_dataset.csv"),
    Path("../data/scaler_df.csv"),
    Path("../data/quantile_df.csv"),
    Path("../data/max_abs_df.csv")    
]     
input_file = input_files[2]
print("Start processing using: ",input_file)
df = pd.read_csv(input_file).astype('float32')
df = df[~df.isin([np.nan, np.inf, -np.inf,-9999.0]).any(1)]
y = df['target'].values
X = df.drop("target",axis=1).values

model = XGBRegressor(objective='reg:squarederror',tree_method='gpu_hist', gpu_id=0, n_jobs=-1)
# rfecv = RFECV(estimator=model,min_features_to_select=4)
rfecv = RFECV(estimator=model)

pipeline = Pipeline([('Feature Selection', rfecv), ('Model', model)])

cv = KFold(n_splits=3,shuffle=True, random_state=3)    
cv_scores = cross_val_score(pipeline, X, y, scoring='r2', cv=cv, n_jobs=-1, verbose=2)
pipeline.fit(X,y)


mean_score = np.mean(cv_scores)
print("cv_scores: ", cv_scores)
# summarize all features
X = df.drop("target",axis=1)
for i in range(X.shape[1]):
    print("Feature Name: ",X.columns.values[i])
    print('Column: %d, Selected %s, Rank: %.3f' % (i, rfecv.support_[i], rfecv.ranking_[i]))

print('Optimal number of features : %d' % rfecv.n_features_)
print("Grid Scores: ", rfecv.grid_scores_)
# Out:
# Start processing using:  ../data/quantile_df.csv
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  9.1min finished
# cv_scores:  [0.77159396 0.76980071 0.77331537]
# Feature Name:  tpi_300
# Column: 0, Selected False, Rank: 5.000
# Feature Name:  Grav_lane_clip
# Column: 1, Selected False, Rank: 13.000
# Feature Name:  clim_PTA_albers
# Column: 2, Selected True, Rank: 1.000
# Feature Name:  be-30y-85m-avg-ND-RED-BLUE.filled.lzw.nodata
# Column: 3, Selected True, Rank: 1.000
# Feature Name:  be-30y-85m-avg_BLUE+SWIR2
# Column: 4, Selected False, Rank: 20.000
# Feature Name:  3dem_mag1_fin
# Column: 5, Selected True, Rank: 1.000
# Feature Name:  ceno_euc_aust1
# Column: 6, Selected True, Rank: 1.000
# Feature Name:  be-l8-all-85m-avg-BLUE.filled.lzw.nodata
# Column: 7, Selected True, Rank: 1.000
# Feature Name:  be-30y-85m-avg-ND-SWIR1-NIR.filled.lzw.nodata
# Column: 8, Selected False, Rank: 14.000
# Feature Name:  Thorium_2016
# Column: 9, Selected False, Rank: 11.000
# Feature Name:  dem_fill
# Column: 10, Selected True, Rank: 1.000
# Feature Name:  relief_elev_focalrange1000m_3s
# Column: 11, Selected True, Rank: 1.000
# Feature Name:  LATITUDE_GRID1_clip
# Column: 12, Selected True, Rank: 1.000
# Feature Name:  LOC_distance_to_coast
# Column: 13, Selected True, Rank: 1.000
# Feature Name:  be-30y-85m-avg-SWIR1.filled.lzw.nodata
# Column: 14, Selected False, Rank: 10.000
# Feature Name:  clim_EPA_albers
# Column: 15, Selected False, Rank: 12.000
# Feature Name:  be-30y-85m-avg-ND-SWIR1-SWIR2.filled.lzw.nodata
# Column: 16, Selected True, Rank: 1.000
# Feature Name:  relief_roughness
# Column: 17, Selected True, Rank: 1.000
# Feature Name:  LONGITUDE_GRID1_clip
# Column: 18, Selected True, Rank: 1.000
# Feature Name:  si_geol1
# Column: 19, Selected True, Rank: 1.000
# Feature Name:  be-30y-85m-avg-SWIR2.filled.lzw.nodata
# Column: 20, Selected False, Rank: 8.000
# Feature Name:  national_Wii_RF_multirandomforest_prediction
# Column: 21, Selected False, Rank: 2.000
# Feature Name:  3dem_mag2
# Column: 22, Selected True, Rank: 1.000
# Feature Name:  clim_WDA_albers
# Column: 23, Selected False, Rank: 6.000
# Feature Name:  Dose_2016
# Column: 24, Selected True, Rank: 1.000
# Feature Name:  be-30y-85m-avg-GREEN.filled.lzw.nodata
# Column: 25, Selected False, Rank: 21.000
# Feature Name:  be-30y-85m-avg-CLAY-PC2.filled.lzw.nodata
# Column: 26, Selected False, Rank: 19.000
# Feature Name:  Clim_Prescott_LindaGregory
# Column: 27, Selected True, Rank: 1.000
# Feature Name:  Potassium_2016
# Column: 28, Selected True, Rank: 1.000
# Feature Name:  mrvbf_9
# Column: 29, Selected True, Rank: 1.000
# Feature Name:  Rad2016K_Th
# Column: 30, Selected True, Rank: 1.000
# Feature Name:  be-30y-85m-avg-ND-NIR-GREEN.filled.lzw.nodata
# Column: 31, Selected True, Rank: 1.000
# Feature Name:  be-l8-all-85m-avg-NIR.filled.lzw.nodata
# Column: 32, Selected False, Rank: 23.000
# Feature Name:  be-30y-85m-avg-RED.filled.lzw.nodata
# Column: 33, Selected False, Rank: 17.000
# Feature Name:  slope_fill2
# Column: 34, Selected False, Rank: 24.000
# Feature Name:  clim_RSM_albers
# Column: 35, Selected True, Rank: 1.000
# Feature Name:  relief_elev_focalrange300m_3s
# Column: 36, Selected True, Rank: 1.000
# Feature Name:  relief_mrvbf_3s_mosaic
# Column: 37, Selected True, Rank: 1.000
# Feature Name:  Rad2016U_Th
# Column: 38, Selected False, Rank: 4.000
# Feature Name:  3dem_mag0.fin
# Column: 39, Selected False, Rank: 15.000
# Feature Name:  s2-dpca-85m_1
# Column: 40, Selected False, Rank: 7.000
# Feature Name:  s2-dpca-85m_2
# Column: 41, Selected False, Rank: 18.000
# Feature Name:  s2-dpca-85m_3
# Column: 42, Selected False, Rank: 22.000
# Feature Name:  water-85m_1
# Column: 43, Selected False, Rank: 16.000
# Feature Name:  water-85m_2
# Column: 44, Selected False, Rank: 9.000
# Feature Name:  water-85m_3
# Column: 45, Selected False, Rank: 3.000
# Feature Name:  saga_wetSM_85_reprojected
# Column: 46, Selected True, Rank: 1.000
# Optimal number of features : 24
# Grid Scores:  [0.08782533 0.16334009 0.25593785 0.31476351 0.3500432  0.3521662
#  0.40413716 0.41969449 0.4525993  0.46570907 0.46560367 0.46482476
#  0.47237231 0.48424277 0.49487153 0.46549155 0.4671749  0.49219198
#  0.4616101  0.4945429  0.48177568 0.50633109 0.51303779 0.51629745
#  0.50903639 0.49367352 0.48439912 0.50465457 0.48153193 0.49204782
#  0.47004998 0.49311363 0.49309909 0.49641742 0.49703372 0.50136931
#  0.5063536  0.50083506 0.49813297 0.50976647 0.51093375 0.50477161
#  0.50348539 0.4995756  0.49967885 0.50079787 0.5099499 ]
# CPU times: user 8min 37s, sys: 31.3 s, total: 9min 8s
# Wall time: 13min 36s

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
plt.xlabel('Number of features selected')
plt.ylabel('Cross validation score ')
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
plt.show()

# %%
rfecv.estimator_
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=0,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=-1, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='gpu_hist', validate_parameters=1, verbosity=None)

# %%
data_1_itration = {}
for i,ranking in enumerate(rfecv.ranking_):
    data_1_itration[X.columns.values[i]]=ranking
    

sorted_data_1_itration = {k: v for k, v in sorted(data_1_itration.items(), key=lambda item: item[1])}
for k in sorted_data_1_itration:
    print(k, data_1_itration[k])
# Out:
# clim_PTA_albers 1
# be-30y-85m-avg-ND-RED-BLUE.filled.lzw.nodata 1
# 3dem_mag1_fin 1
# ceno_euc_aust1 1
# be-l8-all-85m-avg-BLUE.filled.lzw.nodata 1
# dem_fill 1
# relief_elev_focalrange1000m_3s 1
# LATITUDE_GRID1_clip 1
# LOC_distance_to_coast 1
# be-30y-85m-avg-ND-SWIR1-SWIR2.filled.lzw.nodata 1
# relief_roughness 1
# LONGITUDE_GRID1_clip 1
# si_geol1 1
# 3dem_mag2 1
# Dose_2016 1
# Clim_Prescott_LindaGregory 1
# Potassium_2016 1
# mrvbf_9 1
# Rad2016K_Th 1
# be-30y-85m-avg-ND-NIR-GREEN.filled.lzw.nodata 1
# clim_RSM_albers 1
# relief_elev_focalrange300m_3s 1
# relief_mrvbf_3s_mosaic 1
# saga_wetSM_85_reprojected 1
# national_Wii_RF_multirandomforest_prediction 2
# water-85m_3 3
# Rad2016U_Th 4
# tpi_300 5
# clim_WDA_albers 6
# s2-dpca-85m_1 7
# be-30y-85m-avg-SWIR2.filled.lzw.nodata 8
# water-85m_2 9
# be-30y-85m-avg-SWIR1.filled.lzw.nodata 10
# Thorium_2016 11
# clim_EPA_albers 12
# Grav_lane_clip 13
# be-30y-85m-avg-ND-SWIR1-NIR.filled.lzw.nodata 14
# 3dem_mag0.fin 15
# water-85m_1 16
# be-30y-85m-avg-RED.filled.lzw.nodata 17
# s2-dpca-85m_2 18
# be-30y-85m-avg-CLAY-PC2.filled.lzw.nodata 19
# be-30y-85m-avg_BLUE+SWIR2 20
# be-30y-85m-avg-GREEN.filled.lzw.nodata 21
# s2-dpca-85m_3 22
# be-l8-all-85m-avg-NIR.filled.lzw.nodata 23
# slope_fill2 24
